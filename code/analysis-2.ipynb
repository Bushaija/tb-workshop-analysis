# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../_data/tb-rsqa-cleaned.csv')

# %%
df.columns
# Out:
# Index(['province', 'district', 'hf_tb_type', 'hf_name', 'hf_type',
#        'genexpert_site', 'fy', 'summary_group', 'no', 'normes', 'item_name',
#        'num', 'den'],
#       dtype='object')

# %%
df.head()
# Out:
#   province district hf_tb_type  hf_name        hf_type genexpert_site  \
# 0   North   Gakenke         CT  ruli cs  health center             NO
# 1   North   Gakenke         CT  ruli cs  health center             NO
# 2   North   Gakenke         CT  ruli cs  health center             NO
# 3   North   Gakenke         CT  ruli cs  health center             NO
# 4   North   Gakenke         CT  ruli cs  health center             NO
#
#           fy                                      summary_group no  \
# 0  2020-2021  Are algorithms for TB screening, TB diagnosis ...  1
# 1  2020-2021  Are TB monitoring tools existing, update and w...  2
# 2  2020-2021  Is active case finding conducted in TB high ri...  3
# 3  2020-2021  Is active case finding conducted in TB high ri...  4
# 4  2020-2021  Are TB diagnostics continuously functional (mi...  5
#
#                                               normes  \
# 0  Toute FOSA doit rendre disponible des algorith...
# 1  Les prestataires doivent avoir les connaissanc...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            item_name  num   den
# 0  Les services VIH/ARV, Consultations externes, ...  3.0   4.0
# 1  Les prestataires des services ARV, Consultatio...  4.0   4.0
# 2  Sur 10 nouveaux prisonniers entrés au cours de...  NaN  10.0
# 3  Sur 10 nouveaux prisonniers sortants au cours ...  NaN  10.0
# 4  Sur les 10 derniers patients hospitalises( 5 p...  NaN  10.0

# %% [markdown]
# `Data cleaning`

# %%
df['fy'].unique()
# Out:
# array(['2020-2021', '2021-2022', '2022-2023', '2023-2024'], dtype=object)

# %%
df['fy_year'] = df['fy'].str.extract(r'(\d{4})').astype(int)
df['fy_year'].unique()
# Out:
# array([2020, 2021, 2022, 2023])

# %%
df.columns
# Out:
# Index(['province', 'district', 'hf_tb_type', 'hf_name', 'hf_type',
#        'genexpert_site', 'fy', 'summary_group', 'no', 'normes', 'item_name',
#        'num', 'den', 'fy_year'],
#       dtype='object')

# %%
summary_item_scores = (
    df.groupby(
        ['summary_group', "genexpert_or_microscopy", 'item_name', 'hf_name', 'hf_tb_type', 'hf_type', 'fy']
    )
    .agg({'num': 'sum', 'den': 'sum'})
    .reset_index()
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 2
#       1 summary_item_scores = (
# ----> 2     df.groupby(
#       3         ['summary_group', "genexpert_or_microscopy", 'item_name', 'hf_name', 'hf_tb_type', 'hf_type', 'fy']
#       4     )
#       5     .agg({'num': 'sum', 'den': 'sum'})
#       6     .reset_index()
#       7 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
#    8255     axis=axis,
#    8256     level=level,
#    8257     as_index=as_index,
#    8258     sort=sort,
#    8259     group_keys=group_keys,
#    8260     observed=observed,
#    8261     dropna=dropna,
#    8262 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\groupby\groupby.py:931, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#     928 self.dropna = dropna
#     930 if grouper is None:
# --> 931     grouper, exclusions, obj = get_grouper(
#     932         obj,
#     933         keys,
#     934         axis=axis,
#     935         level=level,
#     936         sort=sort,
#     937         observed=observed,
#     938         dropna=self.dropna,
#     939     )
#     941 self.obj = obj
#     942 self.axis = obj._get_axis_number(axis)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\groupby\grouper.py:985, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#     983         in_axis, level, gpr = False, gpr, None
#     984     else:
# --> 985         raise KeyError(gpr)
#     986 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     987     # Add key to exclusions
#     988     exclusions.add(gpr.key)
#
# KeyError: 'genexpert_or_microscopy'

# %% [markdown]
# `screening, diagnosis, and treatment`

# %%
# Define mapping of summary_group to section
section_mapping = {
    "Is active case finding conducted in TB high risk groups?[Questions 2, 8 and 9]": "screening",
    "Are TB diagnostics continuously functional (microscopy and Expert) and their results available timely (microscopy, expert and culture)?[Questions 3, 4, 5, 6 and 7]": "diagnosis",
    "Are TB patients early initiated on TB treatment and on ART (if indicated), and their bacteriological control performed according to guidelines?[Questions 16, 17, 18 and 19]": "treatment",
    "Does the BMI monitored for TB Patients and nutritional support provided to the eligible patients?[Questions New_70 and New_71]": "treatment"
}

summary_item_scores["section"] = summary_item_scores["summary_group"].map(section_mapping)

# %% [markdown]
# `average score`

# %%
# Compute the average score as (sum of num / sum of den) * 100
summary_item_scores['avg_score'] = (summary_item_scores['num'] / summary_item_scores['den']) * 100

# %% [markdown]
# `Filter only rows which are either 'screening', 'treatment', or 'diagnostic'`

# %%
filtered_summary = summary_item_scores[summary_item_scores["section"].isin(["screening", "treatment", "diagnosis"])]

# %% [markdown]
# `remove prisoners questions`

# %%
# Define the items to exclude
items_to_exclude = [
    "Sur 10 nouveaux prisonniers entrÃ©s au cours de la pÃ©riode evaluÃ©e, combien ont beneficiÃ© du screening TB Ã¡ l'entrÃ©e",
    "Sur 10 nouveaux prisonniers sortants au cours de la pÃ©riode evaluÃ©e, combien ont beneficiÃ© du screening TB Ã¡ la sortie"
]

# Filter out rows where item_name is in items_to_exclude
filtered_summary = filtered_summary[~filtered_summary["item_name"].isin(items_to_exclude)]

# %%
filtered_summary.columns
# Out:
# Index(['summary_group', 'genexpert_or_microscopy', 'item_name', 'hf_name',
#        'hf_tb_type', 'hf_type', 'fy', 'num', 'den', 'section', 'avg_score'],
#       dtype='object')

# %%
filtered_summary.shape
# Out:
# (6700, 11)

# %%
# Define valid cases
valid_df = filtered_summary[
    (filtered_summary["num"] <= filtered_summary["den"]) &  # num must not be greater than den
    ~(filtered_summary["num"].isna() & filtered_summary["den"] > 0) &  # Exclude cases where num is NaN but den > 0
    ~((filtered_summary["num"] == 0) & (filtered_summary["den"] == 0)) &  # Exclude cases where both num and den are 0
    ~(filtered_summary["den"].isna())  # Exclude cases where den is NaN (new fix)
]

invalid_df = filtered_summary[
    (filtered_summary["num"] > filtered_summary["den"]) |  # Invalid if num > den
    ((filtered_summary["num"].isna()) & (filtered_summary["den"] > 0)) |  # Invalid if num is NaN but den > 0
    ((filtered_summary["num"] == 0) & (filtered_summary["den"] == 0)) |  # Invalid if both num and den are 0
    (filtered_summary["den"].isna()) |  # Invalid if den is NaN
    ((filtered_summary["num"].isna()) & (filtered_summary["den"] == 0))  # NEW FIX: Invalid if num is NaN and den = 0
]

# %%
print("valid size: ", valid_df.shape)
print("invalid size: ", invalid_df.shape)

# %%
stop

# %%
valid_df.columns
# Out:
# Index(['summary_group', 'genexpert_or_microscopy', 'item_name', 'hf_name',
#        'hf_tb_type', 'hf_type', 'fy', 'num', 'den', 'section', 'avg_score'],
#       dtype='object')

# %%
fy_summary = valid_df.groupby(
    ['section', 'hf_tb_type', 'hf_type', 'fy']
).apply(lambda x: (x["num"].sum() / x["den"].sum()) * 100).reset_index(name="overall_score")
fy_summary
# Out:
#       section hf_tb_type              hf_type         fy  overall_score
# 0   diagnosis        CDT        health center  2020-2021      80.508965
# 1   diagnosis        CDT        health center  2021-2022      43.314567
# 2   diagnosis        CDT        health center  2022-2023      41.993958
# 3   diagnosis        CDT        health center  2023-2024      54.724409
# 4   diagnosis        CDT  hospital (dh,ph,rh)  2020-2021      83.333333
# 5   diagnosis        CDT  hospital (dh,ph,rh)  2021-2022      80.077745
# 6   diagnosis        CDT  hospital (dh,ph,rh)  2022-2023      79.719388
# 7   diagnosis        CDT  hospital (dh,ph,rh)  2023-2024      82.928724
# 8   diagnosis         CT        health center  2020-2021      40.702341
# 9   diagnosis         CT        health center  2021-2022      32.321429
# 10  diagnosis         CT        health center  2022-2023      31.575964
# 11  diagnosis         CT        health center  2023-2024      27.361723
# 12  screening        CDT        health center  2020-2021      85.362517
# 13  screening        CDT        health center  2021-2022      67.896275
# 14  screening        CDT        health center  2022-2023      42.250923
# 15  screening        CDT        health center  2023-2024      41.680000
# 16  screening        CDT  hospital (dh,ph,rh)  2020-2021      60.661765
# 17  screening        CDT  hospital (dh,ph,rh)  2021-2022      20.165094
# 18  screening        CDT  hospital (dh,ph,rh)  2022-2023       8.459215
# 19  screening        CDT  hospital (dh,ph,rh)  2023-2024      22.757402
# 20  screening         CT        health center  2020-2021      68.536372
# 21  screening         CT        health center  2021-2022      69.201827
# 22  screening         CT        health center  2022-2023      37.398374
# 23  screening         CT        health center  2023-2024      40.851993
# 24  treatment        CDT        health center  2020-2021      81.562100
# 25  treatment        CDT        health center  2021-2022      72.090261
# 26  treatment        CDT        health center  2022-2023      71.182266
# 27  treatment        CDT        health center  2023-2024      70.526316
# 28  treatment        CDT  hospital (dh,ph,rh)  2020-2021      82.956522
# 29  treatment        CDT  hospital (dh,ph,rh)  2021-2022      83.980583
# 30  treatment        CDT  hospital (dh,ph,rh)  2022-2023      62.711864
# 31  treatment        CDT  hospital (dh,ph,rh)  2023-2024      80.976864
# 32  treatment         CT        health center  2020-2021      76.101695
# 33  treatment         CT        health center  2021-2022      67.832765
# 34  treatment         CT        health center  2022-2023      48.120301
# 35  treatment         CT        health center  2023-2024      64.211369

# %%
# hf_counts = fy_summary.groupby(["section", "hf_tb_type", "fy", "hf_type"])["hf_name"].nunique().reset_index(name="hf_count")
# overall_scores = fy_summary.groupby(["section", "hf_tb_type", "fy", "hf_type"]).apply(lambda x: (x["percentage"].sum() / x["percentage"].shape[0])).reset_index(name="overall_score")
# invalid_result_df = pd.merge(hf_counts, overall_scores, on=["section", "fy", "hf_type"], how="left")
# invalid_result_df

# %%
# First calculate the overall_score as you were doing
fy_summary = valid_df.groupby(["genexpert_or_microscopy", "hf_tb_type", 'section', 'hf_type', 'fy']).apply(
    lambda x: (x["num"].sum() / x["den"].sum()) * 100
).reset_index(name="overall_score")

# Now calculate the hf_count by counting unique health facilities in each group
hf_counts = valid_df.groupby(["genexpert_or_microscopy", "hf_tb_type", 'section', 'hf_type', 'fy'])["hf_name"].nunique().reset_index(name="hf_count")

# Merge the two dataframes to get all the columns you need
result_df = pd.merge(fy_summary, hf_counts, on=["genexpert_or_microscopy", "hf_tb_type", 'section', 'hf_type', 'fy'], how="left")

# %%
result_df
# Out:
#    genexpert_or_microscopy hf_tb_type    section              hf_type  \
# 0                       no        CDT  diagnosis        health center
# 1                       no        CDT  diagnosis        health center
# 2                       no        CDT  diagnosis        health center
# 3                       no        CDT  diagnosis        health center
# 4                       no        CDT  screening        health center
# 5                       no        CDT  screening        health center
# 6                       no        CDT  screening        health center
# 7                       no        CDT  screening        health center
# 8                       no        CDT  treatment        health center
# 9                       no        CDT  treatment        health center
# 10                      no        CDT  treatment        health center
# 11                      no        CDT  treatment        health center
# 12                      no         CT  diagnosis        health center
# 13                      no         CT  diagnosis        health center
# 14                      no         CT  diagnosis        health center
# 15                      no         CT  diagnosis        health center
# 16                      no         CT  screening        health center
# 17                      no         CT  screening        health center
# 18                      no         CT  screening        health center
# 19                      no         CT  screening        health center
# 20                      no         CT  treatment        health center
# 21                      no         CT  treatment        health center
# 22                      no         CT  treatment        health center
# 23                      no         CT  treatment        health center
# 24                     yes        CDT  diagnosis        health center
# 25                     yes        CDT  diagnosis        health center
# 26                     yes        CDT  diagnosis        health center
# 27                     yes        CDT  diagnosis        health center
# 28                     yes        CDT  diagnosis  hospital (dh,ph,rh)
# 29                     yes        CDT  diagnosis  hospital (dh,ph,rh)
# 30                     yes        CDT  diagnosis  hospital (dh,ph,rh)
# 31                     yes        CDT  diagnosis  hospital (dh,ph,rh)
# 32                     yes        CDT  screening        health center
# 33                     yes        CDT  screening        health center
# 34                     yes        CDT  screening        health center
# 35                     yes        CDT  screening        health center
# 36                     yes        CDT  screening  hospital (dh,ph,rh)
# 37                     yes        CDT  screening  hospital (dh,ph,rh)
# 38                     yes        CDT  screening  hospital (dh,ph,rh)
# 39                     yes        CDT  screening  hospital (dh,ph,rh)
# 40                     yes        CDT  treatment        health center
# 41                     yes        CDT  treatment        health center
# 42                     yes        CDT  treatment        health center
# 43                     yes        CDT  treatment        health center
# 44                     yes        CDT  treatment  hospital (dh,ph,rh)
# 45                     yes        CDT  treatment  hospital (dh,ph,rh)
# 46                     yes        CDT  treatment  hospital (dh,ph,rh)
# 47                     yes        CDT  treatment  hospital (dh,ph,rh)
#
#            fy  overall_score  hf_count
# 0   2020-2021      80.058867        23
# 1   2021-2022      40.008503        24
# 2   2022-2023      41.941748        10
# 3   2023-2024      48.507463        21
# 4   2020-2021      82.198953        23
# 5   2021-2022      68.913561        24
# 6   2022-2023      40.284360        10
# 7   2023-2024      40.067340        21
# 8   2020-2021      82.091918        23
# 9   2021-2022      71.551724        24
# 10  2022-2023      67.500000        10
# 11  2023-2024      72.051696        21
# 12  2020-2021      40.702341        46
# 13  2021-2022      32.321429        40
# 14  2022-2023      31.575964        18
# 15  2023-2024      27.361723        41
# 16  2020-2021      68.536372        45
# 17  2021-2022      69.201827        40
# 18  2022-2023      37.398374        18
# 19  2023-2024      40.851993        41
# 20  2020-2021      76.101695        46
# 21  2021-2022      67.832765        40
# 22  2022-2023      48.120301        18
# 23  2023-2024      64.211369        41
# 24  2020-2021      82.162162         5
# 25  2021-2022      59.183673         5
# 26  2022-2023      42.176871         3
# 27  2023-2024      70.663265         8
# 28  2020-2021      83.333333        21
# 29  2021-2022      80.077745        21
# 30  2022-2023      79.719388         8
# 31  2023-2024      82.928724        42
# 32  2020-2021      96.835443         5
# 33  2021-2022      56.018519         5
# 34  2022-2023      49.166667         3
# 35  2023-2024      45.682451         8
# 36  2020-2021      60.661765        17
# 37  2021-2022      20.165094        21
# 38  2022-2023       8.459215         8
# 39  2023-2024      22.757402        42
# 40  2020-2021      79.333333         5
# 41  2021-2022      74.657534         5
# 42  2022-2023      84.883721         3
# 43  2023-2024      66.525424         8
# 44  2020-2021      82.956522        21
# 45  2021-2022      83.980583        21
# 46  2022-2023      62.711864         8
# 47  2023-2024      80.976864        42

# %%
result_df.to_csv("../output/result_df-5.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[269], line 1
# ----> 1 result_df.to_csv("../output/result_df-5.csv", index=False)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
#    3777     errors=errors,
#    3778     compression=compression,
#    3779     quoting=quoting,
#    3780     columns=columns,
#    3781     index_label=index_label,
#    3782     mode=mode,
#    3783     chunksize=chunksize,
#    3784     quotechar=quotechar,
#    3785     date_format=date_format,
#    3786     doublequote=doublequote,
#    3787     escapechar=escapechar,
#    3788     storage_options=storage_options,
#    3789 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\formats\format.py:1186, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1165     created_buffer = False
#    1167 csv_formatter = CSVFormatter(
#    1168     path_or_buf=path_or_buf,
#    1169     lineterminator=lineterminator,
#    (...)
#    1184     formatter=self.fmt,
#    1185 )
# -> 1186 csv_formatter.save()
#    1188 if created_buffer:
#    1189     assert isinstance(path_or_buf, StringIO)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\formats\csvs.py:240, in CSVFormatter.save(self)
#     236 """
#     237 Create the writer & save.
#     238 """
#     239 # apply compression and byte/text conversion
# --> 240 with get_handle(
#     241     self.filepath_or_buffer,
#     242     self.mode,
#     243     encoding=self.encoding,
#     244     errors=self.errors,
#     245     compression=self.compression,
#     246     storage_options=self.storage_options,
#     247 ) as handles:
#     248     # Note: self.encoding is irrelevant here
#     249     self.writer = csvlib.writer(
#     250         handles.handle,
#     251         lineterminator=self.lineterminator,
#    (...)
#     256         quotechar=self.quotechar,
#     257     )
#     259     self._save()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: '../output/result_df-5.csv'
